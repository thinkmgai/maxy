# %% [markdown]
# ### 배포 - npm build 후에 배포

# %%
import paramiko

import os
def get_file_list(path):
    return [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]

hostname = "maxy.iptime.org"
# hostname = "192.168.10.177"
username = "songs"
password = "thdghqkr74"
port = 8022
remote_path = "/mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch"
# SSH 클라이언트 객체 생성
ssh_client = paramiko.SSHClient()
ssh_client.set_missing_host_key_policy(paramiko.AutoAddPolicy())

# %%
def check_remote_dir(sftp, remote_path):
    """원격 경로가 없으면 계층적으로 생성"""
    dirs = remote_path.strip('/').split('/')
    path = ''
    for d in dirs:
        path += '/' + d
        try:
            sftp.stat(path)  # 존재 여부 확인
        except FileNotFoundError:
            sftp.mkdir(path)
            

def FileUpload(sftp,SourceFile,TargetFile):
    try:
        with sftp.open(TargetFile, "wb") as remote_file, open(SourceFile, "rb") as local_file:
            chunk_size = 1024 * 1024  # 32KB씩 다운로드
            downloaded_size = 0
            while True:
                data = local_file.read(chunk_size)
                if not data:
                    break
                remote_file.write(data)
                downloaded_size += len(data)
                print(f"업로드중: {SourceFile} -> {downloaded_size}")
        print(f"완료: {TargetFile}")
    except Exception as e:
        print(f"FileUpload 오류 발생: {SourceFile}-{TargetFile}-{e}")
        
        
def FolderUpdate(sftp,SourceFolder,TargetFolder):
    try:
        # flist = get_file_list(f"{SourceFolder}")
        flist = os.listdir(f"{SourceFolder}")
        for file in flist:
            if file == "." or file == "..":
                continue
            if os.path.isdir(f"{SourceFolder}/{file}"):
                check_remote_dir(sftp,f"{TargetFolder}/{file}")
                FolderUpdate(sftp,f"{SourceFolder}/{file}",f"{TargetFolder}/{file}")
                continue
            SourceFile = f"{SourceFolder}/{file}"
            TargetFile = f"{TargetFolder}/{file}"
            FileUpload(sftp,SourceFile,TargetFile)
    except Exception as e:
        print(f"FolderUpdate 오류 발생: {SourceFolder}-{TargetFolder}-{e}")

# %%
ssh_client = paramiko.SSHClient()
ssh_client.set_missing_host_key_policy(paramiko.AutoAddPolicy())

try:
    ssh_client.connect(hostname, port, username, password)
    TargetPath = f"{remote_path}"
    SourcePath = f"."
    # SFTP 클라이언트 생성
    sftp = ssh_client.open_sftp()
    FileUploadDir = ["clickhouse","ClickHouseComm","jobs"]
    for folder in FileUploadDir:
        check_remote_dir(sftp,f"{TargetPath}/{folder}")
        FolderUpdate(sftp,f"{SourcePath}/{folder}",f"{TargetPath}/{folder}")    
    UploadFiles = [
        (f"{SourcePath}/scheduler.py",f"{TargetPath}/scheduler.py"),
        (f"{SourcePath}/settings.py",f"{TargetPath}/settings.py")
    ]
    for SourceFile,TargetFile in UploadFiles:
        FileUpload(sftp,SourceFile,TargetFile)
    sftp.close()
except Exception as e:
    print(f"오류 발생: {e}")
finally:
    ssh_client.close()
# Out:
# 업로드중: ./clickhouse/__init__.py -> 227
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/clickhouse/__init__.py
# 업로드중: ./clickhouse/__pycache__/schema.cpython-312.pyc -> 1861
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/clickhouse/__pycache__/schema.cpython-312.pyc
# 업로드중: ./clickhouse/__pycache__/__init__.cpython-312.pyc -> 468
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/clickhouse/__pycache__/__init__.cpython-312.pyc
# 업로드중: ./clickhouse/sql/resources/loadingtime.xml -> 1096
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/clickhouse/sql/resources/loadingtime.xml
# 업로드중: ./clickhouse/sql/resources/metrics.xml -> 6756
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/clickhouse/sql/resources/metrics.xml
# 업로드중: ./clickhouse/sql/resources/responsetime.xml -> 1093
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/clickhouse/sql/resources/responsetime.xml
# 업로드중: ./ClickHouseComm/config.py -> 858
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/ClickHouseComm/config.py
# 업로드중: ./ClickHouseComm/client.py -> 1114
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/ClickHouseComm/client.py
# 업로드중: ./ClickHouseComm/__init__.py -> 253
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/ClickHouseComm/__init__.py
# 업로드중: ./ClickHouseComm/__pycache__/sql_loader.cpython-312.pyc -> 3168
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/ClickHouseComm/__pycache__/sql_loader.cpython-312.pyc
# 업로드중: ./ClickHouseComm/__pycache__/config.cpython-312.pyc -> 1921
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/ClickHouseComm/__pycache__/config.cpython-312.pyc
# 업로드중: ./ClickHouseComm/__pycache__/client.cpython-312.pyc -> 1552
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/ClickHouseComm/__pycache__/client.cpython-312.pyc
# 업로드중: ./ClickHouseComm/__pycache__/__init__.cpython-312.pyc -> 403
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/ClickHouseComm/__pycache__/__init__.cpython-312.pyc
# 업로드중: ./ClickHouseComm/sql_loader.py -> 1980
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/ClickHouseComm/sql_loader.py
# 업로드중: ./jobs/batch_logmeter.py -> 9683
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/batch_logmeter.py
# 업로드중: ./jobs/basic_information_page.py -> 3901
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/basic_information_page.py
# 업로드중: ./jobs/daily_device_page_summary.py -> 8605
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/daily_device_page_summary.py
# 업로드중: ./jobs/__pycache__/loading_time_scatter.cpython-312.pyc -> 13405
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/__pycache__/loading_time_scatter.cpython-312.pyc
# 업로드중: ./jobs/__pycache__/daily_device_page_summary.cpython-312.pyc -> 11809
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/__pycache__/daily_device_page_summary.cpython-312.pyc
# 업로드중: ./jobs/__pycache__/logmeter_stackmax.cpython-312.pyc -> 6101
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/__pycache__/logmeter_stackmax.cpython-312.pyc
# 업로드중: ./jobs/__pycache__/response_time_scatter.cpython-312.pyc -> 11730
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/__pycache__/response_time_scatter.cpython-312.pyc
# 업로드중: ./jobs/__pycache__/basic_information_device.cpython-312.pyc -> 7884
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/__pycache__/basic_information_device.cpython-312.pyc
# 업로드중: ./jobs/__pycache__/basic_information_page.cpython-312.pyc -> 5996
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/__pycache__/basic_information_page.cpython-312.pyc
# 업로드중: ./jobs/__pycache__/batch_logmeter.cpython-312.pyc -> 11875
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/__pycache__/batch_logmeter.cpython-312.pyc
# 업로드중: ./jobs/loading_time_scatter.py -> 11504
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/loading_time_scatter.py
# 업로드중: ./jobs/logmeter_stackmax.py -> 4263
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/logmeter_stackmax.py
# 업로드중: ./jobs/basic_information_device.py -> 6401
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/basic_information_device.py
# 업로드중: ./jobs/response_time_scatter.py -> 9139
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/jobs/response_time_scatter.py
# 업로드중: ./scheduler.py -> 3773
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/scheduler.py
# 업로드중: ./settings.py -> 966
# 완료: /mnt/HDII/Projects/maxy/compose/maxy-react/maxy_batch/settings.py

# %%
# flist = get_file_list(f".next")
# os.listdir(path=".next")
